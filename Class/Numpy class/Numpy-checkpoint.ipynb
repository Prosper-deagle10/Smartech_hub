# %%
a = [2, 3, 5, 4]
b = [1, -3, 4, 9]
list(map(lambda a,b: a + b, [2, 3, 5, 4],[1, -3, 4, 9]))
# Out:
# [3, 0, 9, 13]

# %%
a = [2, 3, 5, 4]
b = [1, -3, 4, 9]
c = []

for i in range(len(a)):
    c.append(a[i] + b[i])
print(c)
# Out:
# [3, 0, 9, 13]

# %%
a = 2, 3, 5, 4
b = 1, -3, 4, 9
list(zip(a,b))
# Out:
# [(2, 1), (3, -3), (5, 4), (4, 9)]

# %%
a = 2, 3, 5, 4
b = 1, -3, 4, 9
c = []
list(zip(a,b))
for item in zip(a,b):
    c.append(item[0] + item[1])
print(c)
# Out:
# [3, 0, 9, 13]

# %%
# 
a = 2, 3, 5, 4
b = 1, -3, 4, 9
c = []
list(zip(a,b))
for x,y in zip(a,b):
    c.append(x + y)
print(c)
# Out:
# [3, 0, 9, 13]

# %% [markdown]
# # Numpy

# %%
import numpy as np
# pick a list and comvert it to a numpy array
a = np.array(a)
b = np.array(b)
c = a+b
print(a)
print(b)
print(c)
# Out:
# [2 3 5 4]
# [ 1 -3  4  9]
# [ 3  0  9 13]

# %%
import numpy as np
# pick a list, tuple or a set and comvert it to a numpy array
a = np.array(a)
b = np.array(b)
c = a+b
print(a)
print(b)
c
# Out:
# [2 3 5 4]
# [ 1 -3  4  9]
# array([ 3,  0,  9, 13])

# %%
import numpy as np
# pick a list and comvert it to a numpy array
a = np.array(a)
b = np.array(b)
c = a+b
d = a*b 
print(a)
print(b)
print(c)
print(d)
# Out:
# [2 3 5 4]
# [ 1 -3  4  9]
# [ 3  0  9 13]
# [ 2 -9 20 36]

# %%
# Attributes of array.
#1. dim
print(a.ndim)
# Out:
# 1

# %%
print(a.size)
# Out:
# 4

# %%
print(a.dtype)
# Out:
# int32

# %%
c = np.array([2, 4, 9, 3.2])
print(c.dtype)
print(c.shape)
c
# Out:
# float64
# (4,)
# array([2. , 4. , 9. , 3.2])

# %%
x = np.array([[4,9],
             [7,2],
             [1.4,1]])
print(x.ndim)
print(x.size)
print(x.shape)
print(x.dtype)
# Out:
# 2
# 6
# (3, 2)
# float64

# %%
# arange in numpy
a =np.arange(5)
b =np.arange(4,8,1.2)
c =np.linspace(10,40)
print(a)
print(b)
print(c)
# Out:
# [0 1 2 3 4]
# [4.  5.2 6.4 7.6]
# [10.         10.6122449  11.2244898  11.83673469 12.44897959 13.06122449
#  13.67346939 14.28571429 14.89795918 15.51020408 16.12244898 16.73469388
#  17.34693878 17.95918367 18.57142857 19.18367347 19.79591837 20.40816327
#  21.02040816 21.63265306 22.24489796 22.85714286 23.46938776 24.08163265
#  24.69387755 25.30612245 25.91836735 26.53061224 27.14285714 27.75510204
#  28.36734694 28.97959184 29.59183673 30.20408163 30.81632653 31.42857143
#  32.04081633 32.65306122 33.26530612 33.87755102 34.48979592 35.10204082
#  35.71428571 36.32653061 36.93877551 37.55102041 38.16326531 38.7755102
#  39.3877551  40.        ]

# %%
a =np.arange(5)
b =np.arange(4,8,1.2)
c =np.linspace(10,40,15)
print(a)
print(b)
print(c)
# Out:
# [0 1 2 3 4]
# [4.  5.2 6.4 7.6]
# [10.         12.14285714 14.28571429 16.42857143 18.57142857 20.71428571
#  22.85714286 25.         27.14285714 29.28571429 31.42857143 33.57142857
#  35.71428571 37.85714286 40.        ]

# %%
k =np.random.randint(5)
print(k)
# Out:
# 1

# %%
# The enumerate function in pyhton.
# The enumerate() function is a built-in function in Python that returns an enumerate object. 
# An enumerate object is a sequence of tuples where each tuple consists of an index and the corresponding 
# value from a given iterable. In other words, the enumerate() function 
# adds a counter to an iterable and returns it as an enumerate object. For example:

s = [1,3,4,5,6]
l = [5,6,8,9,3]

for i in enumerate(s):
    print(i)
# Out:
# (0, 1)
# (1, 3)
# (2, 4)
# (3, 5)
# (4, 6)

# %%
s = [1,3,4,5,6]
l = [5,6,8,9,3]

for i in enumerate(s + l):
    print(i)
# Out:
# (0, 1)
# (1, 3)
# (2, 4)
# (3, 5)
# (4, 6)
# (5, 5)
# (6, 6)
# (7, 8)
# (8, 9)
# (9, 3)

# %%
# This is a very common way to generate random integers in NumPy. 
#The "j" variable will contain a NumPy array of random integers between 5 and 10. 
#The number of elements in the array will be determined by the size of the array you initialize "j" with. 
#For example, if you initialize "j" with "j = np.random.randint(5, 10, 3)", 
# you will get an array of 3 random integers between 5 and 10.

j = np.random.randint(5,10)
print(j)
# Out:
# 9

# %%
j = np.random.randint(5,10)
print(j)
# Out:
# 6

# %%
j = np.random.randint(5,10,3)
print(j)
# Out:
# [7 6 8]

# %%
import numpy as np
j = np.random.randint(5,20,10)
print(j)
# Out:
# [ 9 11 17 15  7 19  9 16 19 19]

# %%
j = np.random.randint(5,10,3)
print(j)
# Out:
# [8 6 6]

# %%
j = np.random.randint(5,10,2)
print(j)
# Out:
# [9 5]

# %%
# Reshaping change the position of the rows and columes as can be seen below.
#

a = np.array([2, 3, 5, 4])
b = np.array([1, -3, 4, 9])

print(a.shape)
print(b.size)
# Out:
# (4,)
# 4

# %%
a = np.array([[2, 3, 5, 4], [1, -3, 4, 9]])

print(a.shape)
print(a.ndim)
print(a.size)
# Out:
# (2, 4)
# 2
# 8

# %%
a.reshape(4,2)
# Out:
# array([[ 2,  3],
#        [ 5,  4],
#        [ 1, -3],
#        [ 4,  9]])

# %% [markdown]
# # Day 2 on Numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
np.ones(4)
# Out:
# array([1., 1., 1., 1.])

# %%
ages = np.random.randint(18,50,9)
ages
# Out:
# array([42, 20, 48, 37, 26, 32, 28, 44, 18])

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.bar(np.arange(9), ages)
# Out:
# <BarContainer object of 9 artists>

# %%
names = ["Maria", "Charles", "Ezekiel", "Malv", "whyte", "George", "vincent", "oxward", "charity"]
plt.bar(names,ages,color = "r")
plt.grid(1)

# %%
names = ["Maria", "Charles", "Ezekiel", "Malv", "whyte", "George", "vincent", "oxward", "charity"]
plt.barh(names,ages,color = "r")
plt.grid(1)

# %%
names = ["Maria", "Charles", "Ezekiel", "Malv", "whyte", "George", "vincent", "oxward", "charity"]
plt.bar(names,ages,color = "r")
plt.grid(1)
plt.xticks(np.arange(9), names, rotation = 40 )
# Out:
# ([<matplotlib.axis.XTick at 0x1abda12fe50>,
# ...
#  [Text(0, 0, 'Maria'),
#   Text(1, 0, 'Charles'),
#   Text(2, 0, 'Ezekiel'),
#   Text(3, 0, 'Malv'),
#   Text(4, 0, 'whyte'),
#   Text(5, 0, 'George'),
#   Text(6, 0, 'vincent'),
#   Text(7, 0, 'oxward'),
#   Text(8, 0, 'charity')])

# %%
names = ["Maria", "Charles", "Ezekiel", "Malv", "whyte", "George", "vincent", "oxward", "charity"]
plt.bar(names,ages,color = "r")
plt.grid(1)
plt.xticks(np.arange(9), names, rotation = 40 );

# %%
plt.pie(ages)
# Out:
# ([<matplotlib.patches.Wedge at 0x1abda237f10>,
# ...
#  [Text(0.9917907139568455, 0.475763785621574, ''),
#   Text(0.49154552027917076, 0.9840645311632157, ''),
#   Text(-0.2837578486625042, 1.0627706635593719, ''),
#   Text(-1.0111513682445143, 0.4330968834998089, ''),
#   Text(-1.0612446741814834, -0.289412752865933, ''),
#   Text(-0.6975496531393756, -0.8505436387423851, ''),
#   Text(-0.05269476014347776, -1.098737121541555, ''),
#   Text(0.724362476904448, -0.827827881901095, ''),
#   Text(1.0798519379023348, -0.209570494604017, '')])

# %%
plt.pie(ages, labels = names);

# %%
plt.pie(ages, labels = names, autopct = "%.2f%%");

# %%
plt.pie(ages, labels = names, autopct = "%.2f%%", explode = (0.2,0,0,0,0,0,0,0,0));

# %%
plt.pie(ages, labels = names, autopct = "%.2f%%", explode = (0.2,0,0.6,0,0,0,0,0,0.4));

# %%
plt.pie(ages, labels = names, autopct = lambda value: f"{round(360*value/100,1)}$^0$",explode = (0.2,0,0,0,0,0,0,0,0));
