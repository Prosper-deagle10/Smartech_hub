# %%
import pandas as pd

# %%
# To get the csv file that I will be working with from my desktop.

df = pd.read_csv(r'C:\Users\ACER\Desktop\country-data.csv') # This is a dataset that displays country-data.

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
df.shape
# Out:
# (167, 10)

# %%
df.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=167, step=1)

# %%
df.isna()
# Out:
#      country  child_mort  exports  health  imports  income  inflation  \
# 0      False       False    False   False    False   False      False
# 1      False       False    False   False    False   False      False
# 2      False       False    False   False    False   False      False
# 3      False       False    False   False    False   False      False
# 4      False       False    False   False    False   False      False
# ..       ...         ...      ...     ...      ...     ...        ...
# 162    False       False    False   False    False   False      False
# 163    False       False    False   False    False   False      False
# 164    False       False    False   False    False   False      False
# 165    False       False    False   False    False   False      False
# 166    False       False    False   False    False   False      False
#
#      life_expec  total_fer   gdpp
# 0         False      False  False
# 1         False      False  False
# ...

# %%
df.isna().any()
# Out:
# country       False
# child_mort    False
# exports       False
# health        False
# imports       False
# income        False
# inflation     False
# life_expec    False
# total_fer     False
# gdpp          False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 162    False
# 163    False
# 164    False
# 165    False
# 166    False
# Length: 167, dtype: bool

# %%
df.duplicated().any()
# Out:
# False

# %%
df[['country', 'imports']]
# Out:
#                  country  imports
# 0            Afghanistan     44.9
# 1                Albania     48.6
# 2                Algeria     31.4
# 3                 Angola     42.9
# 4    Antigua and Barbuda     58.9
# ..                   ...      ...
# 162              Vanuatu     52.7
# 163            Venezuela     17.6
# 164              Vietnam     80.2
# 165                Yemen     34.4
# 166               Zambia     30.9
#
# [167 rows x 2 columns]

# %%
df.loc[0:10,'country': 'imports']
# Out:
#                 country  child_mort  exports  health  imports
# 0           Afghanistan        90.2     10.0    7.58     44.9
# 1               Albania        16.6     28.0    6.55     48.6
# 2               Algeria        27.3     38.4    4.17     31.4
# 3                Angola       119.0     62.3    2.85     42.9
# 4   Antigua and Barbuda        10.3     45.5    6.03     58.9
# 5             Argentina        14.5     18.9    8.10     16.0
# 6               Armenia        18.1     20.8    4.40     45.3
# 7             Australia         4.8     19.8    8.73     20.9
# 8               Austria         4.3     51.3   11.00     47.8
# 9            Azerbaijan        39.2     54.3    5.88     20.7
# 10              Bahamas        13.8     35.0    7.89     43.7

# %%
df.head(5)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
import pandas as pd

# %%
bank = pd.read_csv(r'C:\Users\ACER\Desktop\bank.csv')

# %%
bank
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
bank.shape
# Out:
# (11162, 17)

# %%
bank.marital
# Out:
# 0        married
# 1        married
# 2        married
# 3        married
# 4        married
#           ...
# 11157     single
# 11158    married
# 11159     single
# 11160    married
# 11161    married
# Name: marital, Length: 11162, dtype: object

# %%
bank.marital =='single'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11157     True
# 11158    False
# 11159     True
# 11160    False
# 11161    False
# Name: marital, Length: 11162, dtype: bool

# %%
bank.loc[bank.marital =='single']
# Out:
#        age            job marital  education default  balance housing loan  \
# 5       42     management  single   tertiary      no        0     yes  yes
# 9       28       services  single  secondary      no     5090     yes   no
# 10      38         admin.  single  secondary      no      100     yes   no
# 13      46    blue-collar  single   tertiary      no      460     yes   no
# 14      31     technician  single   tertiary      no      703     yes   no
# ...    ...            ...     ...        ...     ...      ...     ...  ...
# 11139   30  self-employed  single   tertiary      no     2593      no   no
# 11153   43         admin.  single  secondary      no       35      no   no
# 11156   34    blue-collar  single  secondary      no      -72     yes   no
# 11157   33    blue-collar  single    primary      no        1     yes   no
# 11159   32     technician  single  secondary      no       29      no   no
#
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
bank[["age"]]
# Out:
#        age
# 0       59
# 1       56
# 2       41
# 3       55
# 4       54
# ...    ...
# 11157   33
# 11158   39
# 11159   32
# 11160   43
# 11161   34
#
# [11162 rows x 1 columns]

# %%
bank[bank["age"] < 50]
# Out:
#        age          job  marital  education default  balance housing loan  \
# 2       41   technician  married  secondary      no     1270     yes   no
# 5       42   management   single   tertiary      no        0     yes  yes
# 8       37   technician  married  secondary      no        1     yes   no
# 9       28     services   single  secondary      no     5090     yes   no
# 10      38       admin.   single  secondary      no      100     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
age_diff = bank[bank["age"] < 50]
print(age_diff)
# Out:
#        age          job  marital  education default  balance housing loan  \
# 2       41   technician  married  secondary      no     1270     yes   no
# 5       42   management   single   tertiary      no        0     yes  yes
# 8       37   technician  married  secondary      no        1     yes   no
# 9       28     services   single  secondary      no     5090     yes   no
# 10      38       admin.   single  secondary      no      100     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
bank.age
# Out:
# 0        59
# 1        56
# 2        41
# 3        55
# 4        54
#          ..
# 11157    33
# 11158    39
# 11159    32
# 11160    43
# 11161    34
# Name: age, Length: 11162, dtype: int64

# %%
bank.age[bank["age"] < 30]
# Out:
# 9        28
# 12       29
# 20       28
# 29       28
# 32       26
#          ..
# 11066    28
# 11071    25
# 11080    25
# 11088    27
# 11102    26
# Name: age, Length: 1551, dtype: int64

# %%
bank.age.isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11157    False
# 11158    False
# 11159    False
# 11160    False
# 11161    False
# Name: age, Length: 11162, dtype: bool

# %%
bank.age.isna().any()
# Out:
# False

# %%
bank.marital[bank["marital"] == 'single']
# Out:
# 5        single
# 9        single
# 10       single
# 13       single
# 14       single
#           ...
# 11139    single
# 11153    single
# 11156    single
# 11157    single
# 11159    single
# Name: marital, Length: 3518, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x= bank.marital[bank["marital"] == 'single']

# %%
sns.scatterplot(x)
# Out:
# <Axes: ylabel='marital'>

# %%
bank.head(5)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
bank.head(5).marital
# Out:
# 0    married
# 1    married
# 2    married
# 3    married
# 4    married
# Name: marital, dtype: object

# %%
bank.head(10).marital[bank["marital"] == 'married']
# Out:
# 0    married
# 1    married
# 2    married
# 3    married
# 4    married
# 6    married
# 8    married
# Name: marital, dtype: object

# %%
bank.head(10).marital
# Out:
# 0     married
# 1     married
# 2     married
# 3     married
# 4     married
# 5      single
# 6     married
# 7    divorced
# 8     married
# 9      single
# Name: marital, dtype: object

# %%
extr = bank.head(10).marital
sns.scatterplot(extr)
# Out:
# <Axes: ylabel='marital'>

# %%
extr = bank.head(10).marital
plt.hist(extr)

plt.title('First Ten Customers')
plt.xlabel('Marital Status')
plt.ylabel('Range')
plt.show()

# %%
bank.age
# Out:
# 0        59
# 1        56
# 2        41
# 3        55
# 4        54
#          ..
# 11157    33
# 11158    39
# 11159    32
# 11160    43
# 11161    34
# Name: age, Length: 11162, dtype: int64

# %%
bank.loc[0:10,'age': 'marital']
# Out:
#     age         job   marital
# 0    59      admin.   married
# 1    56      admin.   married
# 2    41  technician   married
# 3    55    services   married
# 4    54      admin.   married
# 5    42  management    single
# 6    56  management   married
# 7    60     retired  divorced
# 8    37  technician   married
# 9    28    services    single
# 10   38      admin.    single

# %%
bank[['age','marital']]
# Out:
#        age  marital
# 0       59  married
# 1       56  married
# 2       41  married
# 3       55  married
# 4       54  married
# ...    ...      ...
# 11157   33   single
# 11158   39  married
# 11159   32   single
# 11160   43  married
# 11161   34  married
#
# [11162 rows x 2 columns]

# %%
bank.head(10)[['age','marital']]
# Out:
#    age   marital
# 0   59   married
# 1   56   married
# 2   41   married
# 3   55   married
# 4   54   married
# 5   42    single
# 6   56   married
# 7   60  divorced
# 8   37   married
# 9   28    single
