# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import simpledialog
from tkinter import font

master = tk.Tk()
master.title("Rich Text Note-Taking App")


# Creating a Text widget for note-taking
text = tk.Text(master, wrap=tk.WORD, bg = "white")
text.pack(fill=tk.BOTH, expand=True)

# Creating a toolbar with formatting buttons
toolbar = tk.Frame(master, bg = "pink")
toolbar.pack(fill=tk.X)


def set_bold():
    current_tags = text.tag_names("sel.first")
    if "bold" in current_tags:
        text.tag_remove("bold", "sel.first", "sel.last")
    else:
        text.tag_add("bold", "sel.first", "sel.last")
        bold_font = font.nametofont(text.tag_cget("bold", "font"))
        bold_font.configure(weight="bold")
        text.tag_configure("bold", font=bold_font)

def set_italic():
    current_tags = text.tag_names("sel.first")
    if "italic" in current_tags:
        text.tag_remove("italic", "sel.first", "sel.last")
    else:
        text.tag_add("italic", "sel.first", "sel.last")
        italic_font = font.nametofont(text.tag_cget("italic", "font"))
        italic_font.configure(slant="italic")
        text.tag_configure("italic", font=italic_font)

def set_underline():
    current_tags = text.tag_names("sel.first")
    if "underline" in current_tags:
        text.tag_remove("underline", "sel.first", "sel.last")
    else:
        text.tag_add("underline", "sel.first", "sel.last")
        text.tag_configure("underline", underline=True)

def change_font(font_family):
    text.tag_add(font_family, "sel.first", "sel.last")
    text.tag_configure(font_family, font=(font_family, text.tag_cget("normal", "size")))

def change_color(color):
    text.tag_add(color, "sel.first", "sel.last")
    text.tag_configure(color, foreground=color)

def insert_bullet():
    text.insert("insert", "• ", "bullet")

def save_file():
    note_text = text.get("1.0", "end-1c")
    filename = simpledialog.asksaveasfilename(defaultextension=".txt", filetypes=[("Text Files", "*.txt")])
    if filename:
        with open(filename, "w") as file:
            file.write(note_text)
        messagebox.showinfo("Info", "File saved successfully.")

def open_file():
    filename = simpledialog.askopenfilename(filetypes=[("Text Files", "*.txt")])
    if filename:
        with open(filename, "r") as file:
            note_text = file.read()
            text.delete("1.0", "end")
            text.insert("1.0", note_text)

bold_button = tk.Button(toolbar, text="Bold", command=set_bold)
bold_button.pack(side=tk.LEFT)

italic_button = tk.Button(toolbar, text="Italic", command=set_italic)
italic_button.pack(side=tk.LEFT)

underline_button = tk.Button(toolbar, text="Underline", command=set_underline)
underline_button.pack(side=tk.LEFT)

font_family_var = tk.StringVar()
font_family_var.set("Arial")
font_family_dropdown = tk.OptionMenu(toolbar, font_family_var, "Arial", "Times New Roman", "Courier New", command=lambda _: change_font(font_family_var.get()))
font_family_dropdown.pack(side=tk.LEFT)

color_var = tk.StringVar()
color_var.set("black")
color_dropdown = tk.OptionMenu(toolbar, color_var, "black", "red", "blue", "green", command=lambda _: change_color(color_var.get()))
color_dropdown.pack(side=tk.LEFT)

bullet_button = tk.Button(toolbar, text="Bullet Point", command=insert_bullet)
bullet_button.pack(side=tk.LEFT)

# Creating a menu for saving and loading notes
menu = tk.Menu(master)
master.config(menu=menu)
file_menu = tk.Menu(menu)
menu.add_cascade(label="File", menu=file_menu)
file_menu.add_command(label="Save", command=save_file)
file_menu.add_command(label="Open", command=open_file)
file_menu.add_separator()
file_menu.add_command(label="Exit", command=master.quit)

master.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\AppData\Local\Temp\ipykernel_640\2444703269.py", line 25, in set_bold
#     bold_font = font.nametofont(text.tag_cget("bold", "font"))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\font.py", line 23, in nametofont
#     return Font(name=name, exists=True, root=root)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\font.py", line 87, in __init__
#     raise tkinter._tkinter.TclError(
# _tkinter.TclError: named font font1 does not already exist
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\AppData\Local\Temp\ipykernel_640\2444703269.py", line 35, in set_italic
#     italic_font = font.nametofont(text.tag_cget("italic", "font"))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\font.py", line 23, in nametofont
#     return Font(name=name, exists=True, root=root)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\font.py", line 87, in __init__
#     raise tkinter._tkinter.TclError(
# _tkinter.TclError: named font font2 does not already exist
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\__init__.py", line 4013, in __call__
#     self.__callback(self.__value, *args)
#   File "C:\Users\ACER\AppData\Local\Temp\ipykernel_640\2444703269.py", line 85, in <lambda>
#     font_family_dropdown = tk.OptionMenu(toolbar, font_family_var, "Arial", "Times New Roman", "Courier New", command=lambda _: change_font(font_family_var.get()))
#                                                                                                                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\AppData\Local\Temp\ipykernel_640\2444703269.py", line 49, in change_font
#     text.tag_configure(font_family, font=(font_family, text.tag_cget("normal", "size")))
#                                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ACER\anaconda3\Lib\tkinter\__init__.py", line 3920, in tag_cget
#     return self.tk.call(self._w, 'tag', 'cget', tagName, option)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _tkinter.TclError: tag "normal" isn't defined in text widget

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import simpledialog
from tkinter import font

master = tk.Tk()
master.title("Rich Text Note-Taking App")


# Creating a Text widget for note-taking
text = tk.Text(master, wrap=tk.WORD, bg = "white")
text.pack(fill=tk.BOTH, expand=True)

# Creating a toolbar with formatting buttons
toolbar = tk.Frame(master, bg = "pink")
toolbar.pack(fill=tk.X)


def set_bold():
    current_tags = text.tag_names("sel.first")
    if "bold" in current_tags:
        text.tag_remove("bold", "sel.first", "sel.last")
    else:
        text.tag_add("bold", "sel.first", "sel.last")
        bold_font = font.nametofont(text.tag_cget("bold", "font"))
        bold_font.configure(weight="bold")
        text.tag_configure("bold", font=bold_font)

def set_italic():
    current_tags = text.tag_names("sel.first")
    if "italic" in current_tags:
        text.tag_remove("italic", "sel.first", "sel.last")
    else:
        text.tag_add("italic", "sel.first", "sel.last")
        italic_font = font.nametofont(text.tag_cget("italic", "font"))
        italic_font.configure(slant="italic")
        text.tag_configure("italic", font=italic_font)

def set_underline():
    current_tags = text.tag_names("sel.first")
    if "underline" in current_tags:
        text.tag_remove("underline", "sel.first", "sel.last")
    else:
        text.tag_add("underline", "sel.first", "sel.last")
        text.tag_configure("underline", underline=True)

def change_font(font_family):
    text.tag_add(font_family, "sel.first", "sel.last")
    text.tag_configure(font_family, font=(font_family, text.tag_cget("normal", "size")))

def change_color(color):
    text.tag_add(color, "sel.first", "sel.last")
    text.tag_configure(color, foreground=color)

def insert_bullet():
    text.insert("insert", "• ", "bullet")

def save_file():
    note_text = text.get("1.0", "end-1c")
    filename = simpledialog.asksaveasfilename(defaultextension=".txt", filetypes=[("Text Files", "*.txt")])
    if filename:
        with open(filename, "w") as file:
            file.write(note_text)
        messagebox.showinfo("Info", "File saved successfully.")

def open_file():
    filename = simpledialog.askopenfilename(filetypes=[("Text Files", "*.txt")])
    if filename:
        with open(filename, "r") as file:
            note_text = file.read()
            text.delete("1.0", "end")
            text.insert("1.0", note_text)

bold_button = tk.Button(toolbar, text="Bold", command=set_bold)
bold_button.pack(side=tk.LEFT)

italic_button = tk.Button(toolbar, text="Italic", command=set_italic)
italic_button.pack(side=tk.LEFT)

underline_button = tk.Button(toolbar, text="Underline", command=set_underline)
underline_button.pack(side=tk.LEFT)

font_family_var = tk.StringVar()
font_family_var.set("Arial")
font_family_dropdown = tk.OptionMenu(toolbar, font_family_var, "Arial", "Times New Roman", "Courier New", command=lambda _: change_font(font_family_var.get()))
font_family_dropdown.pack(side=tk.LEFT)

color_var = tk.StringVar()
color_var.set("black")
color_dropdown = tk.OptionMenu(toolbar, color_var, "black", "red", "blue", "green", command=lambda _: change_color(color_var.get()))
color_dropdown.pack(side=tk.LEFT)

bullet_button = tk.Button(toolbar, text="Bullet Point", command=insert_bullet)
bullet_button.pack(side=tk.LEFT)

# Creating a menu for saving and loading notes
menu = tk.Menu(master)
master.config(menu=menu)
file_menu = tk.Menu(menu)
menu.add_cascade(label="File", menu=file_menu)
file_menu.add_command(label="Save", command=save_file)
file_menu.add_command(label="Open", command=open_file)
file_menu.add_separator()
file_menu.add_command(label="Exit", command=master.quit)

master.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import simpledialog
from tkinter import font

class NoteApp:
    def __init__(self, master):
        self.master = master
        self.master.title("Rich Text Note-Taking App")

        # Text widget for note-taking
        self.text = tk.Text(self.master, wrap=tk.WORD, bg="white")
        self.text.grid(row=0, column=0, sticky="nsew")

        # Toolbar with formatting buttons
        self.toolbar = tk.Frame(self.master, bg="pink")
        self.toolbar.grid(row=1, column=0, sticky="ew")

        # Initialize the toolbar buttons
        self.init_toolbar()

        # Configuring rows and columns to expand with the window
        self.master.grid_rowconfigure(0, weight=1)
        self.master.grid_columnconfigure(0, weight=1)

    def init_toolbar(self):
        # Button for bold
        bold_button = tk.Button(self.toolbar, text="Bold", command=self.set_bold)
        bold_button.grid(row=0, column=0)

        # Button for italic
        italic_button = tk.Button(self.toolbar, text="Italic", command=self.set_italic)
        italic_button.grid(row=0, column=1)

        # Button for underline
        underline_button = tk.Button(self.toolbar, text="Underline", command=self.set_underline)
        underline_button.grid(row=0, column=2)

        # Dropdown for font family
        font_family_var = tk.StringVar()
        font_family_var.set("Arial")
        font_family_dropdown = tk.OptionMenu(self.toolbar, font_family_var, "Arial", "Times New Roman", "Courier New", command=lambda _: self.change_font(font_family_var.get()))
        font_family_dropdown.grid(row=0, column=3)

        # Dropdown for text color
        color_var = tk.StringVar()
        color_var.set("black")
        color_dropdown = tk.OptionMenu(self.toolbar, color_var, "black", "red", "blue", "green", command=lambda _: self.change_color(color_var.get()))
        color_dropdown.grid(row=0, column=4)

        # Button for bullet point
        bullet_button = tk.Button(self.toolbar, text="Bullet Point", command=self.insert_bullet)
        bullet_button.grid(row=0, column=5)

    def set_bold(self):
        # Same implementation as before
        pass

    def set_italic(self):
        # Same implementation as before
        pass

    def set_underline(self):
        # Same implementation as before
        pass

    def change_font(self, font_family):
        # Same implementation as before
        pass

    def change_color(self, color):
        # Same implementation as before
        pass

    def insert_bullet(self):
        # Same implementation as before
        pass


def save_file():
    # Same implementation as before
    pass

def open_file():
    # Same implementation as before
    pass


if __name__ == "__main__":
    root = tk.Tk()
    app = NoteApp(root)

    # Creating a menu for saving and loading notes
    menu = tk.Menu(root)
    root.config(menu=menu)
    file_menu = tk.Menu(menu)
    menu.add_cascade(label="File", menu=file_menu)
    file_menu.add_command(label="Save", command=save_file)
    file_menu.add_command(label="Open", command=open_file)
    file_menu.add_separator()
    file_menu.add_command(label="Exit", command=root.quit)

    root.mainloop()
