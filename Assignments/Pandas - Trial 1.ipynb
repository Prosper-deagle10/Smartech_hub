# %%
import numpy as np
import pandas as pd
np_scores = np.random.randint(16, 90,(4, 7))
scores = pd.DataFrame(np_scores)
scores.index = ['Prosper', 'Whyte', 'Vincent', 'Charity']
scores.columns = ['CHM130', 'MTH110', 'MTH120', 'PHY101', 'CSC120', 'FSB101', 'GES100']
print(scores)
# Out:
#          CHM130  MTH110  MTH120  PHY101  CSC120  FSB101  GES100
# Prosper      83      72      19      74      28      47      86
# Whyte        62      48      89      49      86      17      88
# Vincent      23      63      64      75      61      88      51
# Charity      39      82      28      84      19      80      48

# %%
import matplotlib.pyplot as plt
plt.hist(scores)
plt.show()
